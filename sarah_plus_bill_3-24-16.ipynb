# %% [markdown]
# # what are the goals:
#
#  * specify element
#  * given element, look up available compounds
#  * specify amount of target
#  * specify range of target

# %%
from suggester_interface import get_compound_list

# %%
get_compound_list('Al','oxide')
# Out:
# [u'Al2O3']

# %%
import suggester

# %%
S = suggester.CompoundSuggester()
_Global_S = S

# %%
element = 'xx'
compound_type = 'salt'

# %%
df = S.salt

# %%
df.query_target(element)['Formula'].tolist()
# Out:
# []

# %%
def get_compound_list(element,compound_type,S=None):
    """
    given an element and compound type, return list of known compounds
    
    Parameters
    ----------
    element : str
        name of element to query
        
    compound_type : str
        type of compounds to return
        one of ['acid','oxide','salt','all']
        
    S : CompoundSuggester or None
        CompoundSuggester to query.  If None, use default suggester
        
        
    Returns
    -------
    out : list
        list of compound formulas with element
    """
    
    if S is None:
        S = _Global_S

        
    if compound_type == 'acid':
        df = S.acid
        
    elif compound_type == 'oxide':
        df = S.oxide
        
    elif compound_type == 'salt':
        df = S.salt
        
    elif compound_type == 'all':
        df = S
        
    else:
        raise ValueError('compound_type must be one of ["acid","oxide","salt","all"]')
    
    
    out = df.query_target(element)['Formula'].tolist()
    return out

# %%
S.query_target_all('Al')
# Out:
#          ID                                      Name            Formula  \
# 2     oxide                        Aluminum oxide (Y)              Al2O3
# 11     salt                                  Aluminum                 Al
# 12     salt                          Aluminum acetate        Al(C2H3O2)3
# 16     salt                 Aluminum ammonium sulfate        AlNH4(SO4)2
# 21     salt   Aluminum ammonium sulfate dodecahydrate  AlNH4(SO4)2+12H2O
# 26     salt                       Aluminum antimonide               AlSb
# 28     salt                         Aluminum arsenide               AlAs
# 30     salt                           Aluminum borate        2Al2O3+B2O3
# 33     salt                      Aluminum borohydride           Al(BH4)3
# 36     salt              Aluminum bromate nonahydrate     Al(BrO3)3+9H2O
# 40     salt                          Aluminum bromide              AlBr3
# 42     salt              Aluminum bromide hexahydrate         AlBr3+6H2O
# 46     salt                          Aluminum carbide              Al4C3
# 48     salt             Aluminum chlorate nonahydrate     Al(ClO3)3+9H2O
# 52     salt                         Aluminum chloride              AlCl3
# 54     salt             Aluminum chloride hexahydrate         AlCl3+6H2O
# 58     salt                        Aluminum diacetate    Al(OH)(C2H3O2)2
# 62     salt                         Aluminum diboride               AlB2
# 64     salt                       Aluminum distearate  Al(OH)(C18H35O2)2
# 68     salt                     Aluminum dodecaboride              AlB12
# 70     salt                       Aluminum ethanolate         Al(C2H5O)3
# 74     salt                         Aluminum fluoride               AlF3
# 76     salt             Aluminum fluoride monohydrate           AlF3+H2O
# 80     salt              Aluminum fluoride trihydrate          AlF3+3H2O
# 84     salt   Aluminum hexafluorosilicate nonahydrate    Al2(SiF6)3+9H2O
# 89     salt                          Aluminum hydride               AlH3
# 91     salt                        Aluminum hydroxide            Al(OH)3
# 94     salt                  Aluminum hydroxychloride    Al2(OH)5Cl+2H2O
# 98     salt                    Aluminum hypophosphite         Al(H2PO2)3
# 102    salt                           Aluminum iodide               AlI3
# ...     ...                                       ...                ...
# 1193   salt                       Beryllium aluminate            BeAl2O4
# 1196   salt           Beryllium aluminum metasilicate      Be3Al2(SiO3)6
# 1514   salt                         Calcium aluminate            CaAl2O4
# 1517   salt                Calcium aluminate (β form)           Ca3Al2O6
# 1948   salt               Calcium tetrahydroaluminate          Ca(AlH4)2
# 2129   salt     Cesium aluminum sulfate dodecahydrate   CsAl(SO4)2+12H2O
# 2473   salt                      Cobalt(II) aluminate            CoAl2O4
# 3304   salt                     Diethylchloroaluminum        AlCl(C2H5)2
# 3333   salt                  Diisobutylchloroaluminum        AlCl(C4H9)2
# 4041   salt                        Iron(II) aluminate          Fe(AlO2)2
# 4218   salt                  Lanthanum aluminum oxide             LaAlO3
# 4514   salt                  Lithium aluminum hydride             LiAlH4
# 4517   salt                 Lithium aluminum silicate          LiAlSi2O6
# 4748   salt                       Magnesium aluminate          Mg(AlO2)2
# 4751   salt               Magnesium aluminum silicate   Mg2Al3(AlSi5O18)
# 5383   salt                    Methyldichloroaluminum           AlCl2CH3
# 5545   salt                   Nickel aluminide (NiAl)               NiAl
# 6173   salt            Potassium aluminate trihydrate       K2Al2O4+3H2O
# 6177   salt               Potassium aluminum silicate           KAlSi3O8
# 6181   salt                Potassium aluminum sulfate          KAl(SO4)2
# 6185   salt  Potassium aluminum sulfate dodecahydrate    KAl(SO4)2+12H2O
# 6438   salt                 Rubidium aluminum sulfate         RbAl(SO4)2
# 6442   salt   Rubidium aluminum sulfate dodecahydrate   RbAl(SO4)2+12H2O
# 7247   salt                          Sodium aluminate             NaAlO2
# 7250   salt                   Sodium aluminum hydride             NaAlH4
# 7253   salt     Sodium aluminum sulfate dodecahydrate   NaAl(SO4)2+12H2O
# 7421   salt                Sodium hexafluoroaluminate            Na3AlF6
# 7707   salt               Sodium tetrachloroaluminate            NaAlCl4
# 7989   salt                        Tantalum aluminide              TaAl3
# 8782   salt                    Yttrium aluminum oxide           Y3Al5O12
#
#                       CAS Target  mass_frac
# 2               1344-28-1     Al   0.529251
# 11              7429-90-5     Al   1.000000
# 12               139-12-8     Al   0.132189
# 16              7784-25-0     Al   0.113776
# 21              7784-26-1     Al   0.059519
# 26             25152-52-7     Al   0.181399
# 28             22831-42-1     Al   0.264776
# 30             11121-16-7     Al   0.394549
# 33             16962-07-5     Al   0.377312
# 36            11126-81-1*     Al   0.047103
# 40              7727-15-3     Al   0.101171
# 42    7784-11-04 00:00:00     Al   0.071992
# 46              1299-86-1     Al   0.749705
# 48             15477-33-5     Al   0.061395
# 52              7446-70-0     Al   0.202351
# 54              7784-13-6     Al   0.111756
# 58               142-03-0     Al   0.166474
# 62             12041-50-8     Al   0.555135
# 64               300-92-5     Al   0.044165
# 68             12041-54-2     Al   0.172171
# 70               555-75-9     Al   0.166385
# 74              7784-18-1     Al   0.321298
# 76             32287-65-3     Al   0.264546
# 80             15098-87-0     Al   0.195486
# 84             17099-70-6     Al   0.084012
# 89              7784-21-6     Al   0.899224
# 91             21645-51-2     Al   0.345901
# 94              1327-41-9     Al   0.256377
# 98              7784-22-7     Al   0.121568
# 102             7784-23-8     Al   0.066181
# ...                   ...    ...        ...
# 1193           12004-06-7     Al   0.424997
# 1196            1302-52-9     Al   0.100396
# 1514           12042-68-1     Al   0.341455
# 1517           12042-78-3     Al   0.199720
# 1948           16941-10-9     Al   0.528508
# 2129            7784-17-0     Al   0.047486
# 2473           13820-62-7     Al   0.305059
# 3304              96-10-6     Al   0.223808
# 3333            1779-25-5     Al   0.152729
# 4041           12068-49-4     Al   0.310479
# 4218           12003-65-5     Al   0.126150
# 4514           16853-85-3     Al   0.710895
# 4517           12068-40-5     Al   0.144992
# 4748           12068-51-8     Al   0.379312
# 4751            1302-88-1     Al   0.184504
# 5383             917-65-7     Al   0.238939
# 5545           12003-78-0     Al   0.314929
# 6173          12003-63-3*     Al   0.215677
# 6177            1327-44-2     Al   0.096940
# 6181           10043-67-1     Al   0.104497
# 6185            7784-24-9     Al   0.056876
# 6438           13530-57-9     Al   0.088588
# 6442            7784-29-4     Al   0.051812
# 7247            1302-42-7     Al   0.329163
# 7250           13770-96-2     Al   0.499630
# 7253           10102-71-3     Al   0.058876
# 7421           13775-53-6     Al   0.128519
# 7707            7784-16-9     Al   0.140688
# 7989           12004-76-1     Al   0.309076
# 8782           12005-21-9     Al   0.227263
#
# [100 rows x 6 columns]

# %%
# how do we build a list of available elements

# %%
import periodictable as PT

# %%
#get all elements
element_list = [str(v) for k,v in PT.elements._element.iteritems() if k>0]

# %%
sorted(element_list)
# Out:
# ['Ac',
#  'Ag',
#  'Al',
#  'Am',
#  'Ar',
#  'As',
#  'At',
#  'Au',
#  'B',
#  'Ba',
#  'Be',
#  'Bh',
#  'Bi',
#  'Bk',
#  'Br',
#  'C',
#  'Ca',
#  'Cd',
#  'Ce',
#  'Cf',
#  'Cl',
#  'Cm',
#  'Cn',
#  'Co',
#  'Cr',
#  'Cs',
#  'Cu',
#  'Db',
#  'Ds',
#  'Dy',
#  'Er',
#  'Es',
#  'Eu',
#  'F',
#  'Fe',
#  'Fm',
#  'Fr',
#  'Ga',
#  'Gd',
#  'Ge',
#  'H',
#  'He',
#  'Hf',
#  'Hg',
#  'Ho',
#  'Hs',
#  'I',
#  'In',
#  'Ir',
#  'K',
#  'Kr',
#  'La',
#  'Li',
#  'Lr',
#  'Lu',
#  'Md',
#  'Mg',
#  'Mn',
#  'Mo',
#  'Mt',
#  'N',
#  'Na',
#  'Nb',
#  'Nd',
#  'Ne',
#  'Ni',
#  'No',
#  'Np',
#  'O',
#  'Os',
#  'P',
#  'Pa',
#  'Pb',
#  'Pd',
#  'Pm',
#  'Po',
#  'Pr',
#  'Pt',
#  'Pu',
#  'Ra',
#  'Rb',
#  'Re',
#  'Rf',
#  'Rg',
#  'Rh',
#  'Rn',
#  'Ru',
#  'S',
#  'Sb',
#  'Sc',
#  'Se',
#  'Sg',
#  'Si',
#  'Sm',
#  'Sn',
#  'Sr',
#  'Ta',
#  'Tb',
#  'Tc',
#  'Te',
#  'Th',
#  'Ti',
#  'Tl',
#  'Tm',
#  'U',
#  'Uuh',
#  'Uuq',
#  'V',
#  'W',
#  'Xe',
#  'Y',
#  'Yb',
#  'Zn',
#  'Zr']
